# %%
import pandas as pd
import pyarrow

# %%
df1 = pd.read_parquet('ruslawod30000.parquet')
df1.head()
# Out:
#   pravogovruNd                                        issuedByIPS  docdateIPS  \
# 0    102120762  Постановление Совета Федерации Федерального Со...  28.03.2008
# 1    102120838    Распоряжение Правительства Российской Федерации  02.04.2008
# 2    102024947  Распоряжение Совета Министров - Правительства ...  14.07.1993
# 3    102143503    Распоряжение Правительства Российской Федерации  08.12.2010
# 4    102488542    Приказ Министерства спорта Российской Федерации  26.10.2018
#
#   docNumberIPS    doc_typeIPS  \
# 0        99-СФ  Постановление
# 1        424-р   Распоряжение
# 2       1262-р   Распоряжение
# 3       2197-р   Распоряжение
# 4          914         Приказ
#
#                                           headingIPS  \
# 0  О назначении Дедова Дмитрия Ивановича на должн...
# 1  О награждении Почетной грамотой Правительства ...
# 2  (Утвердить Антоненко Леонида Кузьмича, Бочаров...
# 3  О создании федерального автономного учреждения...
# ...
